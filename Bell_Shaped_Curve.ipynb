# %% [markdown]
# <a href="https://colab.research.google.com/github/shinynyzamerlin-ai/Bell-Shaped-Curve/blob/main/Bell_Shaped_Curve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generate x values
x = np.linspace(-5, 5, 100)

# Generate normal distribution values
y = norm.pdf(x, 0, 1)

# Plot bell-shaped curve
plt.plot(x, y)

# Add title and labels
plt.title("Bell-Shaped Curve (Normal Distribution)")
plt.xlabel("X Values")
plt.ylabel("Probability Density")

# Display graph
plt.show()
